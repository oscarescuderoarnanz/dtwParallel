# %%
# package 1
from dtaidistance import dtw, dtw_ndim
# package 2
from fastdtw import fastdtw
# package 4
from dtw import dtw
# package 5
# from pydtw import dtw2d
# package 6
# from sdtw import SoftDTW
# from sdtw.distance import SquaredEuclidean

import time
from scipy.spatial import distance
import numpy as np

# %%
number_of_repetitions = 30

# %% [markdown]
# * The currently tested packages can only work with distances that do not allow the computation of data of different nature. For this reason, a public data set obtained from https://finance.yahoo.com/ has been used. All data are continuous.

# %% [markdown]
# # 1. dtaidistance. DTW dependent

# %%
# x = np.load('./X_data_2.npy', allow_pickle=True)

# print(x.shape)

# time_dtaidistance_dep = []

# for rep in range(number_of_repetitions):
#     inicio = time.time()

#     dtw_matrix_dep = np.zeros((len(x), len(x)))
#     for i in range(len(x)):
#         for j in range(len(x)):
#             pat1 = x[i]
#             pat2 = x[j]
#             dtw_distance = dtw_ndim.distance(pat1, pat2)
#             dtw_matrix_dep[i,j] = dtw_distance

#     fin = time.time()
#     time_dtaidistance_dep.append(fin-inicio)

# %% [markdown]
# # 2. fastdtw. DTW dependent. There is no possibility to calculate independent DTW.

# %%
x = np.load('../../Data/E2_FinanceData/FinanceData_20days.npy', allow_pickle=True)

print(x.shape)

time_fastdtw_dep = []

for rep in range(number_of_repetitions):
    
    inicio = time.time()
    dtw_matrix = np.zeros((len(x), len(x)))
    for i in range(len(x)):
        for j in range(len(x)):
            pat1 = x[i]
            pat2 = x[j]
            dtw_distance, _ = fastdtw(pat1, pat2)
            dtw_matrix[i,j] = dtw_distance

    fin = time.time()
    time_fastdtw_dep.append(fin-inicio)
    
f = open("fastdtw_vf.txt", "a")
f.write(str(time_fastdtw_dep))
f.close()
# Out:
# (505, 20, 5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 7>()
#      13         pat1 = x[i]
#      14         pat2 = x[j]
# ---> 15         dtw_distance, _ = fastdtw(pat1, pat2)
#      16         dtw_matrix[i,j] = dtw_distance
#      18 fin = time.time()
#
# File ~/.local/lib/python3.8/site-packages/fastdtw/fastdtw.py:53, in fastdtw(x, y, radius, dist)
#      16 ''' return the approximate distance between 2 time series with O(N)
#      17     time and memory complexity
#      18
#    (...)
#      50     (2.0, [(0, 0), (1, 0), (2, 1), (3, 2), (4, 2)])
#      51 '''
#      52 x, y, dist = __prep_inputs(x, y, dist)
# ---> 53 return __fastdtw(x, y, radius, dist)
#
# File ~/.local/lib/python3.8/site-packages/fastdtw/fastdtw.py:73, in __fastdtw(x, y, radius, dist)
#      70 x_shrinked = __reduce_by_half(x)
#      71 y_shrinked = __reduce_by_half(y)
#      72 distance, path = \
# ---> 73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
#      75 return __dtw(x, y, window, dist=dist)
#
# File ~/.local/lib/python3.8/site-packages/fastdtw/fastdtw.py:73, in __fastdtw(x, y, radius, dist)
#      70 x_shrinked = __reduce_by_half(x)
#      71 y_shrinked = __reduce_by_half(y)
#      72 distance, path = \
# ---> 73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
#      75 return __dtw(x, y, window, dist=dist)
#
# File ~/.local/lib/python3.8/site-packages/fastdtw/fastdtw.py:75, in __fastdtw(x, y, radius, dist)
#      72 distance, path = \
#      73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
# ---> 75 return __dtw(x, y, window, dist=dist)
#
# File ~/.local/lib/python3.8/site-packages/fastdtw/fastdtw.py:142, in __dtw(x, y, window, dist)
#     140 for i, j in window:
#     141     dt = dist(x[i-1], y[j-1])
# --> 142     D[i, j] = min((D[i-1, j][0]+dt, i-1, j), (D[i, j-1][0]+dt, i, j-1),
#     143                   (D[i-1, j-1][0]+dt, i-1, j-1), key=lambda a: a[0])
#     144 path = []
#     145 i, j = len_x, len_y
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. dtw-python. No examples of use are available. Complex usage.

# %% [markdown]
# # 4. dtw. DTW dependent. There is no possibility to calculate independent DTW.

# %%
# x = np.load('./X_data_2.npy', allow_pickle=True)

# print(x.shape)

# time_dtw_dep = []

# for rep in range(number_of_repetitions):
    
#     inicio = time.time()
#     dtw_matrix = np.zeros((len(x), len(x)))
#     for i in range(len(x)):
#         for j in range(len(x)):
#             pat1 = x[i]
#             pat2 = x[j]
#             d, cost_matrix, acc_cost_matrix, path = dtw(pat1, pat2, dist=distance.euclidean)
#             dtw_matrix[i,j] = d

#     fin = time.time()
#     time_dtw_dep.append(fin-inicio)

# %% [markdown]
# # 5. pydtw. Does not work for windows. I can't install it even though it fulfills dependencies.

# %% [markdown]
# # 6. soft-dtw. DTW dependent. There is no possibility to calculate independent DTW. I can't install it even though it fulfills dependencies.

# %% [markdown]
# # 7. dtaidistance. DTW independiente

# %%
# x = np.load('./X_data_2.npy', allow_pickle=True)

# print(x.shape)

# time_fastdtw_indep = []

# for rep in range(number_of_repetitions):

#     inicio = time.time()

#     dtw_matrix_indep = np.zeros((len(x), len(x)))
#     for i in range(len(x)):
#         for j in range(len(x)):
#             pat1 = x[i]
#             pat2 = x[j]
#             dtw_i = 0
#             for dim in range(pat1.shape[1]): 
#                 dtw_i += dtw.distance(pat1[:, dim], pat2[:,dim])
#             dtw_matrix_indep[i,j] = dtw_i

#     fin = time.time()
#     time_fastdtw_indep.append(fin-inicio)
