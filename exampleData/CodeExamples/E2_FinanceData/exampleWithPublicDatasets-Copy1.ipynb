# %%
from fastdtw import fastdtw
from dtaidistance import dtw, dtw_ndim

import time

from dtwParallel import dtw_functions


from scipy.spatial import distance
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ## Mi librería

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "d"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_20days.npy', allow_pickle=True)
y = x.copy()

# print(x.shape)
# print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_dep.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("time_dtwParallel_dep.txt", "a")
f.write(str(dicc))
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 28>()
#      35 input_obj.n_threads = n_threads[i]
#      37 inicio = time.time()
# ---> 39 _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)
#      41 fin = time.time()
#      43 times_1.append(fin-inicio)
#
# File ~/.local/lib/python3.8/site-packages/dtwParallel/dtw_functions.py:168, in dtw_tensor_3d(X_1, X_2, input_obj)
#     166 def dtw_tensor_3d(X_1, X_2, input_obj):
# --> 168     dtw_matrix_train = Parallel(n_jobs=input_obj.n_threads)(
#     169         delayed(dtw)(X_1[i], X_2[j], type_dtw=input_obj.type_dtw, dist=input_obj.distance,
#     170                      MTS=input_obj.MTS, get_visualization=input_obj.visualization, check_errors=input_obj.check_errors)
#     171         for i in range(X_1.shape[0])
#     172         for j in range(X_2.shape[0])
#     173     )
#     175     data = np.array(dtw_matrix_train).reshape((X_1.shape[0], X_2.shape[0]))
#     177     if input_obj.DTW_to_kernel:
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/.local/lib/python3.8/site-packages/dtwParallel/dtw_functions.py:143, in dtw(x, y, type_dtw, dist, MTS, get_visualization, check_errors)
#     141         dtw_distance = dtw_ind(x, y, dist)
#     142     else:
# --> 143         dtw_distance, _ = dtw_dep(x, y, dist)
#     144 else:
#     145     dtw_distance, D = dtw_dep(x, y, dist)
#
# File ~/.local/lib/python3.8/site-packages/dtwParallel/dtw_functions.py:123, in dtw_dep(x, y, dist)
#     120 else:
#     121     for i, j in iter_object:
#     122         # Given the function distance as input parameter the distance between x and y is calculated.
# --> 123         dt = dist(x[i - 1], y[j - 1])
#     124         D[i, j] = min((D[i - 1, j][0] + dt, i - 1, j),
#     125                       (D[i, j - 1][0] + dt, i, j - 1),
#     126                       (D[i - 1, j - 1][0] + dt, i - 1, j - 1))
#     128 return D[len(x), len(y)][0], D
#
# File ~/.local/lib/python3.8/site-packages/scipy/spatial/distance.py:528, in euclidean(u, v, w)
#     492 def euclidean(u, v, w=None):
#     493     """
#     494     Computes the Euclidean distance between two 1-D arrays.
#     495
#    (...)
#     526
#     527     """
# --> 528     return minkowski(u, v, p=2, w=w)
#
# File ~/.local/lib/python3.8/site-packages/scipy/spatial/distance.py:488, in minkowski(u, v, p, w)
#     486         root_w = np.power(w, 1/p)
#     487     u_v = root_w * u_v
# --> 488 dist = norm(u_v, ord=p)
#     489 return dist
#
# File ~/.local/lib/python3.8/site-packages/scipy/linalg/_misc.py:177, in norm(a, ord, axis, keepdims, check_finite)
#     174             return lange(*lange_args)
#     176 # fall back to numpy in every other case
# --> 177 return np.linalg.norm(a, ord=ord, axis=axis, keepdims=keepdims)
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py:2526, in norm(x, ord, axis, keepdims)
#    2524     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2525 else:
# -> 2526     sqnorm = x.dot(x)
#    2527 ret = sqrt(sqnorm)
#    2528 if keepdims:
#
# KeyboardInterrupt:

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "i"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_20days.npy', allow_pickle=True)
y = x.copy()

print(x.shape)
print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_ind.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("time_dtwParallel_ind.txt", "a")
f.write(str(dicc))
f.close()

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "i"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_90days.npy', allow_pickle=True)
y = x.copy()

print(x.shape)
print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_ind.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("time_dtwParallel_ind_all.txt", "a")
f.write(str(dicc))
f.close()

# %% [markdown]
# ## Plot figures

# %%
values = []
keys = list(dicc.keys())
for i in range(len(keys)):
    values.append(np.mean(dicc[keys[i]]))
    print(np.mean(dicc[keys[i]]))
    

fig,axis = plt.subplots(1,1,figsize=(8,6))

axis.plot(keys,values,'bo--',linewidth=2,alpha=1)

plt.xticks(keys, n_threads, fontsize=20)
plt.yticks(fontsize=20)
plt.show()
