# %%
from fastdtw import fastdtw
from dtaidistance import dtw, dtw_ndim

import time

from dtwParallel import dtw_functions


from scipy.spatial import distance
import numpy as np

# %% [markdown]
# ## Paper Example

# %% [markdown]
# ## # E9

# %%
from dtwParallel import dtw_functions
from scipy.spatial import distance
import numpy as np

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "d"
        self.MTS = True
        self.n_threads = 100
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
X = np.load('../../Data/E2_FinanceData/FinanceData_20days.npy', allow_pickle=True)
Y = x.copy()

input_obj = Input()
distance_matrix = dtw_functions.dtw_tensor_3d(X, Y, input_obj)
print("Dimensions: ", distance_matrix.shape)
print("\n", distance_matrix)

# %% [markdown]
# ## dtwParallel

# %% [markdown]
# ## 20 days

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "d"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_20days.npy', allow_pickle=True)
x = x[0:256,:,:]
y = x.copy()

print(x.shape)
print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_dep.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("../../results_E2_SyntheticData/dtwParallel_d_256.txt", "a")
f.write(str(dicc))
f.close()
# Out:
# (256, 20, 6)
# (256, 20, 6)

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "i"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_20days.npy', allow_pickle=True)
y = x.copy()

print(x.shape)
print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_ind.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("../../results_E2_SyntheticData/dtwParallel_i.txt", "a")
f.write(str(dicc))
f.close()
# Out:
# (505, 20, 6)
# (505, 20, 6)

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "d"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_20days_Mult5.npy', allow_pickle=True)
y = x.copy()

print(x.shape)
# print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_dep.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("../../results_E2_SyntheticData/dtwParallel_d_Mult5.txt", "a")
f.write(str(dicc))
f.close()

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "d"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_20days_Mult10.npy', allow_pickle=True)
y = x.copy()

print(x.shape)
# print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_dep.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("../../results_E2_SyntheticData/dtwParallel_d_Mult10.txt", "a")
f.write(str(dicc))
f.close()

# %% [markdown]
# ## 90 days

# %%
# PAQUETE DESARROLLADO: DTW DEPENDIENTE

class Input:
    def __init__(self):
        self.check_errors = False 
        self.type_dtw = "i"
        self.MTS = True
        self.n_threads = -1
        self.distance = distance.euclidean
        self.visualization = False
        self.output_file = False
        self.DTW_to_kernel = False
        self.sigma = 1
        
        
x = np.load('../../Data/E2_FinanceData/FinanceData_90days.npy', allow_pickle=True)
y = x.copy()

print(x.shape)
print(y.shape)

number = 2**8
n_threads = [2**n for n in range(number) if 2**n < number]
n_threads.append(-1)

# Hacer 30 veces y quedarme con la media o mediana del tiempo.
dicc = {}
for i in range(len(n_threads)):
    f = open("contador_ind.txt", "a")
    f.write(str(i))
    f.close()
    times_1 = []
    for j in range(30):
        input_obj = Input()
        input_obj.n_threads = n_threads[i]

        inicio = time.time()

        _ = dtw_functions.dtw_tensor_3d(x, y, input_obj)

        fin = time.time()

        times_1.append(fin-inicio)

    dicc[i] = times_1

    
f = open("time_dtwParallel_ind_all.txt", "a")
f.write(str(dicc))
f.close()
